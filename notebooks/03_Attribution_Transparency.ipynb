# %% [markdown]
# # 03: Attribution Transparency
# Traceability and LIME explainability for legal search.

# %%
from irlib import BayesianDocumentRouter, LIMEExplainer
router = BayesianDocumentRouter()
print('Router initialized. Domain routing traceable via Audit IDs.')
