# %% [markdown]
# # 04: Scalability Benchmarking
# Stress test irlib on 300k+ documents.

# %%
from irlib.streaming import StreamingDocumentProcessor
processor = StreamingDocumentProcessor(batch_size=10000)
print('Streaming engine initialized for large-scale ingestion.')
