# %% [markdown]
# # 02: Learning Loop Moat
# Measuring MRR improvement after feedback loop fine-tuning.

# %%
from irlib.training.loop import LearningLoop
from irlib.training.finetuner import LegalFineTuner
loop = LearningLoop()
loop.log_feedback('bail condition', 0, 1.0)
print('Feedback logged successfully.')
